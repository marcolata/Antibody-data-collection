# %%
# Importar funciones
from PTech import proteintech_antibodies
from GTex  import genetex_antibodies

# %%
# ZONA DE USO

no_catalogo = [""]  # Colocar numero de catalogo de interes

# %%
# Para ProteinTech
proteintech_antibodies(no_catalogo)

# %%
# Para GeneTex
genetex_antibodies(no_catalogo)
